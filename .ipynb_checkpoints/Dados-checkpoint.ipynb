# %% [markdown]
# # Dados

# %% [markdown]
# Estrutura dos dados: (parte mais densa tecnicamente)
# * importar os dados com o pacote pandas (3 bases de dados diferentes)
# * incorporar as 3 bases de dados em uma tabela só
# * aprimorar a organização da tabela
# * pegar dados (primeiro os obrigatórios) da tabela
# * apresentar eles de forma informativa (talvez gráficos)

# %%
import pandas as pd 
import html5lib
#teste
#não importei do kaggle, não consegui e não sei se dá pra abrir em qualquer pc sem ter nada instalado

url="https://github.com/talissonmeira/WTH/blob/main/WtoData.csv?raw=true"

df_data = pd.read_csv(url,encoding='latin-1')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9152\1905138144.py:8: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_data = pd.read_csv(url,encoding='latin-1')

# %% [markdown]
# Os dados foram importados de um repositório público que eu criei no GitHub.

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns',25)
df_data.tail()
# Out:
#                  Indicator Category Indicator Code  \
# 97659  Trade in commercial services      ITS_CS_QX
# 97660  Trade in commercial services      ITS_CS_QX
# 97661  Trade in commercial services      ITS_CS_QX
# 97662  Trade in commercial services      ITS_CS_QX
# 97663  Trade in commercial services      ITS_CS_QX
#
#                                                Indicator  \
# 97659  Commercial services exports by main sector  q...
# 97660  Commercial services exports by main sector  q...
# 97661  Commercial services exports by main sector  q...
# 97662  Commercial services exports by main sector  q...
# 97663  Commercial services exports by main sector  q...
#
#       Reporting Economy Code Reporting Economy ISO3A Code Reporting Economy  \
# 97659                    927                          NaN    Euro Area (19)
# 97660                    927                          NaN    Euro Area (19)
# 97661                    927                          NaN    Euro Area (19)
# 97662                    927                          NaN    Euro Area (19)
# 97663                    927                          NaN    Euro Area (19)
#
#       Partner Economy Code Partner Economy ISO3A Code  \
# 97659                  ZX9                        NaN
# 97660                  ZX9                        NaN
# 97661                  ZX9                        NaN
# 97662                  ZX9                        NaN
# 97663                  ZX9                        NaN
#
#                   Partner Economy Product/Sector Classification Code  \
# 97659  Extra Euro Area (19) Trade                               BOP6
# 97660  Extra Euro Area (19) Trade                               BOP6
# 97661  Extra Euro Area (19) Trade                               BOP6
# 97662  Extra Euro Area (19) Trade                               BOP6
# 97663  Extra Euro Area (19) Trade                               BOP6
#
#                            Product/Sector Classification Product/Sector Code  \
# 97659  Services - Extended Balance of Payments Classi...                SPX4
# 97660  Services - Extended Balance of Payments Classi...                SPX4
# 97661  Services - Extended Balance of Payments Classi...                SPX4
# 97662  Services - Extended Balance of Payments Classi...                SPX4
# 97663  Services - Extended Balance of Payments Classi...                SPX4
#
#                Product/Sector Period Code          Period Frequency Code  \
# 97659  Goods-related services          Q1   First Quarter              Q
# 97660  Goods-related services          Q1   First Quarter              Q
# 97661  Goods-related services          Q2  Second Quarter              Q
# 97662  Goods-related services          Q3   Third Quarter              Q
# 97663  Goods-related services          Q4  Fourth Quarter              Q
#
#        Frequency Unit Code               Unit  Year Value Flag Code  \
# 97659  Quarterly       USM  Million US dollar  2022             NaN
# 97660  Quarterly       USM  Million US dollar  2021             NaN
# 97661  Quarterly       USM  Million US dollar  2021             NaN
# 97662  Quarterly       USM  Million US dollar  2021             NaN
# 97663  Quarterly       USM  Million US dollar  2021             NaN
#
#       Value Flag  Text Value         Value
# 97659        NaN         NaN  15312.113403
# 97660        NaN         NaN  13330.434057
# 97661        NaN         NaN  13603.131178
# 97662        NaN         NaN  13175.430665
# 97663        NaN         NaN  15603.408962

# %% [markdown]
# # vvvcv
# * daadasdasd
# * ertsg
#
# zxvsdvxcvcvxc
