# %% [markdown]
# # Dados

# %% [markdown]
# Estrutura dos dados: (parte mais densa tecnicamente)
# * importar os dados com o pacote pandas (3 bases de dados diferentes)
# * incorporar as 3 bases de dados em uma tabela só
# * aprimorar a organização da tabela
# * pegar dados (primeiro os obrigatórios) da tabela
# * apresentar eles de forma informativa (talvez gráficos)

# %%
import pandas as pd 
import html5lib

#não importei do kaggle, não consegui e não sei se dá pra abrir em qualquer pc sem ter nada instalado

url="https://github.com/talissonmeira/WTD/blob/main/WtoMetadata_20221014064149.csv?raw=true"

df_data = pd.read_csv(url,error_bad_lines=False)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11416\153103460.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_data = pd.read_csv(url,error_bad_lines=False)
# Skipping line 2090: expected 21 fields, saw 24
# Skipping line 3312: expected 21 fields, saw 22
# Skipping line 3379: expected 21 fields, saw 22

# %% [markdown]
# Os dados foram importados de um repositório público que eu criei no GitHub. As linhas com problemas foram substituídas por falsas, como são apenas 3 linhas em meio a 3 mil não vejo muito problema

# %%
pd.set_option('display.max_rows', 4)
df_data
# Out:
#                 Indicator Category Indicator Code  \
# 0     Trade in commercial services     ITS_CS_AM5
# 1     Trade in commercial services     ITS_CS_AX5
# ...                            ...            ...
# 3641      Merchandise trade values     ITS_MTV_AM
# 3642      Merchandise trade values     ITS_MTV_AM
#
#                                               Indicator  \
# 0     Commercial services imports by sector – annual...
# 1     Commercial services exports by sector – annual...
# ...                                                 ...
# 3641      Merchandise imports by product group – annual
# 3642      Merchandise imports by product group – annual
#
#      Reporting Economy Code Reporting Economy ISO3A Code  \
# 0                       090                          SLB
# 1                       702                          SGP
# ...                     ...                          ...
# 3641                    201                          NaN
# 3642                    296                          KIR
#
#                       Reporting Economy Partner Economy Code  \
# 0                       Solomon Islands                  000
# 1                             Singapore                  000
# ...                                 ...                  ...
# 3641  Czech and Slovak Federal Republic                  000
# 3642                           Kiribati                  000
#
#      Partner Economy ISO3A Code Partner Economy  \
# 0                           NaN           World
# 1                           NaN           World
# ...                         ...             ...
# 3641                        NaN           World
# 3642                        NaN           World
#
#      Product/Sector Classification Code  ... Product/Sector Code  \
# 0                                  BOP5  ...              S200OS
# 1                                  BOP5  ...                S260
# ...                                 ...  ...                 ...
# 3641                              SITC3  ...                  MI
# 3642                              SITC3  ...                  MI
#
#                                          Product/Sector Period Code Period  \
# 0     Other commercial services (Commercial services...           -      -
# 1                                    Financial services           -      -
# ...                                                 ...         ...    ...
# 3641                          Fuels and mining products           -      -
# 3642                          Fuels and mining products           -      -
#
#      Frequency Code Frequency Unit Code               Unit  \
# 0                 -         -       USM  Million US dollar
# 1                 -         -       USM  Million US dollar
# ...             ...       ...       ...                ...
# 3641              -         -       USM  Million US dollar
# 3642              -         -       USM  Million US dollar
#
#                  Category                                              Value
# 0                Coverage  Starting from 2009, data converted from BPM6 t...
# 1                Coverage  a) Includes FISIM (Financial Intermediation Se...
# ...                   ...                                                ...
# 3641  Method of valuation                          Imports are valued f.o.b.
# 3642  Method of valuation              Until 2011: Imports are valued f.o.b.
#
# [3643 rows x 21 columns]
